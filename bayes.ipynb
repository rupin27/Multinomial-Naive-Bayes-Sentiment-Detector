# %%
from run import *
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rupinmehra/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Q1

# Find the value using equation (1), with no log and no laplace smoothing
truePos1_1, trueNeg1_1, falsePos1_1, falseNeg1_1 = naiveBayes(0.2, 0.2, 0.2, 0.2, logProb=False, laplaceSmooth=False)
# Out:
# Accuracy  is:  0.374631
# Precision is:  0.367178
# Recall    is:  0.348956

# %%
# Now use q1_1 to implement confusion matrix
confusionMatrix(truePos1_1, trueNeg1_1, falsePos1_1, falseNeg1_1, "Naive Bayes without log-probabilities")

# %%
# Repeat the experiment, find the value using equation (5), with log and no laplace smoothing
truePos1_2, trueNeg1_2, falsePos1_2, falseNeg1_2 = naiveBayes(0.2, 0.2, 0.2, 0.2, logProb=True, laplaceSmooth=False)
# Out:
# Accuracy  is:  0.565500
# Precision is:  0.592678
# Recall    is:  0.504338

# %%
# Confusion Matrix
confusionMatrix(truePos1_2, trueNeg1_2, falsePos1_2, falseNeg1_2, "Naive Bayes with log-probabilities")

# %%
#Q2
truePos2_1, trueNeg2_1, falsePos2_1, falseNeg2_1 = naiveBayes(0.2, 0.2, 0.2, 0.2, logProb=True, laplaceSmooth=True, smoothConst=1)
# Out:
# Accuracy  is:  0.826034
# Precision is:  0.861673
# Recall    is:  0.769704

# %%
confusionMatrix(truePos2_1, trueNeg2_1, falsePos2_1, falseNeg2_1, "Naive Bayes with Lapace Smoothing (alpha = 1)")

# %%
# Now have fixed data for q2

alpha = 0.0001
alphaVals = []
accuracyVals = []
while alpha <= 1000:
    truePos2_2, trueNeg2_2, falsePos2_2, falseNeg2_2 = naiveBayes(0.2, 0.2, 0.2, 0.2, logProb=True, laplaceSmooth = True, smoothConst = alpha)
    accuracyVals.append(accuracy(truePos2_2, trueNeg2_2, falsePos2_2, falseNeg2_2))
    alphaVals.append(alpha)
    alpha*=10
# Out:
# Accuracy  is:  0.728820
# Precision is:  0.744681
# Recall    is:  0.691254
# Accuracy  is:  0.752259
# Precision is:  0.790200
# Recall    is:  0.699251
# Accuracy  is:  0.780342
# Precision is:  0.808409
# Recall    is:  0.738029
# Accuracy  is:  0.803320
# Precision is:  0.846386
# Recall    is:  0.751624
# Accuracy  is:  0.827573
# Precision is:  0.872536
# Recall    is:  0.761809
# Accuracy  is:  0.832049
# Precision is:  0.878285
# Recall    is:  0.771567
# Accuracy  is:  0.823034
# Precision is:  0.888723
# Recall    is:  0.731099
# Accuracy  is:  0.802846
# Precision is:  0.866437
# Recall    is:  0.715507

# %%
plt.xscale("log")
plt.xlabel("Alpha Value")
plt.ylabel("Accuracy")
plt.title("Accuracy vs. Alpha")
plt.plot(alphaVals, accuracyVals)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Q3

truePos3, trueNeg3, falsePos3, falseNeg3 = naiveBayes(1, 1, 1, 1, logProb=True, laplaceSmooth=True, smoothConst=10)
# Out:
# Accuracy  is:  0.842560
# Precision is:  0.876208
# Recall    is:  0.797840

# %%
confusionMatrix(truePos3, trueNeg3, falsePos3, falseNeg3, 'Naive Bayes on Data Set with alpha = 10')

# %%
# Q4

truePos4, trueNeg4, falsePos4, falseNeg4 = naiveBayes(0.5, 0.5, 1, 1, logProb=True, laplaceSmooth=True, smoothConst=10)
# Out:
# Accuracy  is:  0.843560
# Precision is:  0.863787
# Recall    is:  0.815760

# %%
confusionMatrix(truePos4, trueNeg4, falsePos4, falseNeg4, r'Naive Bayes on Data Set with alpha = 10 and 50% of the training set')

# %%
# Q6

truePos6, trueNeg6, falsePos6, falseNeg6 = naiveBayes(0.1, 0.5, 1, 1, logProb=True, laplaceSmooth=True, smoothConst=10)
# Out:
# Accuracy		:  0.500200
# Precision	:  1.000000
# Recall		:  0.000400

# %%
confusionMatrix(truePos6, trueNeg6, falsePos6, falseNeg6, 'Naive Bayes on Data Set with alpha = 10')
